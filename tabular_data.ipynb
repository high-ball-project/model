# %% [markdown]
# 코드: https://dacon.io/competitions/official/236011/codeshare/7029?page=1&dtype=recent

# %% [markdown]
# # 정형데이터

# %%
# 라이브러리
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")

# %%
train.head()
# Out:
#            ID                     img_path mask_path  나이       수술연월일  진단명  \
# 0  BC_01_0001  ./train_imgs/BC_01_0001.png         -  63  2015-10-23    1
# 1  BC_01_0002  ./train_imgs/BC_01_0002.png         -  51  2015-10-28    1
# 2  BC_01_0003  ./train_imgs/BC_01_0003.png         -  37  2015-10-29    1
# 3  BC_01_0004  ./train_imgs/BC_01_0004.png         -  54  2016-03-08    1
# 4  BC_01_0005  ./train_imgs/BC_01_0005.png         -  57  2015-10-30    1
#
#    암의 위치  암의 개수  암의 장경   NG  ...  ER_Allred_score   PR  PR_Allred_score  \
# 0      2      1   19.0  2.0  ...              8.0  1.0              6.0
# 1      1      1   22.0  3.0  ...              NaN  0.0              NaN
# 2      2      1    NaN  2.0  ...              7.0  1.0              4.0
# 3      2      1    0.0  3.0  ...              NaN  0.0              NaN
# 4      2      1    8.0  2.0  ...              8.0  0.0              NaN
#
#    KI-67_LI_percent  HER2  HER2_IHC  HER2_SISH  HER2_SISH_ratio  \
# 0              12.0   0.0       1.0        NaN              NaN
# 1              70.0   0.0       0.0        NaN              NaN
# 2               7.0   0.0       1.0        NaN              NaN
# 3               1.0   1.0       3.0        NaN              NaN
# 4               8.0   1.0       2.0        1.0             5.44
#
#    BRCA_mutation  N_category
# 0            NaN           0
# 1            NaN           1
# 2            0.0           0
# 3            NaN           0
# 4            NaN           0
#
# [5 rows x 28 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1000 non-null   object
#  1   img_path           1000 non-null   object
#  2   mask_path          1000 non-null   object
#  3   나이                 1000 non-null   int64
#  4   수술연월일              1000 non-null   object
#  5   진단명                1000 non-null   int64
#  6   암의 위치              1000 non-null   int64
#  7   암의 개수              1000 non-null   int64
#  8   암의 장경              931 non-null    float64
#  9   NG                 949 non-null    float64
#  10  HG                 914 non-null    float64
#  11  HG_score_1         908 non-null    float64
#  12  HG_score_2         908 non-null    float64
#  13  HG_score_3         911 non-null    float64
#  14  DCIS_or_LCIS_여부    1000 non-null   int64
#  15  DCIS_or_LCIS_type  126 non-null    float64
#  16  T_category         996 non-null    float64
#  17  ER                 999 non-null    float64
#  18  ER_Allred_score    703 non-null    float64
#  19  PR                 999 non-null    float64
#  20  PR_Allred_score    547 non-null    float64
#  21  KI-67_LI_percent   765 non-null    float64
#  22  HER2               986 non-null    float64
#  23  HER2_IHC           976 non-null    float64
#  24  HER2_SISH          247 non-null    float64
#  25  HER2_SISH_ratio    175 non-null    float64
#  26  BRCA_mutation      55 non-null     float64
#  27  N_category         1000 non-null   int64
# dtypes: float64(18), int64(6), object(4)
# memory usage: 218.9+ KB

# %%
train.describe()
# Out:
#                 나이          진단명        암의 위치        암의 개수       암의 장경  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  931.000000
# mean     53.679000     1.289000     1.561000     1.133000   18.375564
# std      11.253471     0.796312     0.559099     0.339745   12.037144
# min      25.000000     1.000000     1.000000     1.000000    0.000000
# 25%      46.000000     1.000000     1.000000     1.000000   11.000000
# 50%      52.000000     1.000000     2.000000     1.000000   17.000000
# 75%      62.000000     1.000000     2.000000     1.000000   23.000000
# max      93.000000     4.000000     3.000000     2.000000  110.000000
#
#                NG          HG  HG_score_1  HG_score_2  HG_score_3  ...  \
# count  949.000000  914.000000  908.000000  908.000000  911.000000  ...
# mean     2.070601    1.897155    2.588106    2.144273    1.428101  ...
# std      0.692234    0.713147    0.654011    0.655820    0.714866  ...
# min      1.000000    1.000000    1.000000    1.000000    1.000000  ...
# 25%      2.000000    1.000000    2.000000    2.000000    1.000000  ...
# 50%      2.000000    2.000000    3.000000    2.000000    1.000000  ...
# 75%      3.000000    2.000000    3.000000    3.000000    2.000000  ...
# max      3.000000    3.000000    3.000000    3.000000    4.000000  ...
#
#        ER_Allred_score          PR  PR_Allred_score  KI-67_LI_percent  \
# count       703.000000  999.000000       547.000000        765.000000
# mean          7.014225    0.641642         6.049360         18.037229
# std           1.125879    0.479758         2.734821         18.846473
# min           3.000000    0.000000         2.000000          0.000000
# 25%           7.000000    0.000000         5.000000          5.000000
# 50%           7.000000    1.000000         6.000000         10.000000
# 75%           8.000000    1.000000         7.000000         25.000000
# max           8.000000    1.000000        54.000000         97.000000
#
#              HER2    HER2_IHC   HER2_SISH  HER2_SISH_ratio  BRCA_mutation  \
# count  986.000000  976.000000  247.000000       175.000000      55.000000
# mean     0.247465    1.253074    0.129555         2.460457       0.145455
# std      0.431758    0.939444    0.336495         7.399121       0.524164
# min      0.000000    0.000000    0.000000         0.000000       0.000000
# 25%      0.000000    0.000000    0.000000         1.130000       0.000000
# 50%      0.000000    1.000000    0.000000         1.270000       0.000000
# 75%      0.000000    2.000000    0.000000         1.675000       0.000000
# max      1.000000    3.000000    1.000000        94.000000       2.000000
#
#         N_category
# count  1000.000000
# mean      0.514000
# std       0.500054
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 24 columns]

# %%
train['암의 장경'] = train['암의 장경'].fillna(train['암의 장경'].mean())
train = train.fillna(0)

test['암의 장경'] = test['암의 장경'].fillna(test['암의 장경'].mean())
test = test.fillna(0)

# %%
train.drop(columns=['ID', 'img_path', 'mask_path', '수술연월일'], inplace=True )
test.drop(columns=['ID', 'img_path', '수술연월일'], inplace=True )

# %%
X = train.iloc[:,:23]
Y = train.iloc[:,23:]
Y
# Out:
#      N_category
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0
# ..          ...
# 995           1
# 996           0
# 997           1
# 998           0
# 999           1
#
# [1000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
seed = 42
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
import xgboost as xgb
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc  ### 이 줄과
rc('font', family='AppleGothic') 			## 이 두 줄을 
plt.rcParams['axes.unicode_minus'] = False  ## 추가해줍니다. 

from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import StratifiedShuffleSplit, cross_val_score

import xgboost as xgb
from xgboost import plot_importance
import optuna

# %%
def RF_objective(trial: optuna.trial.Trial):
    params = {
        'objective': 'binary:logistic',
        'eval_metric':'auc',
        'booster':'gbtree',
        'n_estimators': trial.suggest_int("n_estimators", 100, 1000, step=10),
        "max_depth": trial.suggest_int("max_depth", 4, 10),
        
        # 'tree_method':'gpu_hist', 'predictor':'gpu_predictor', 'gpu_id': 0, # GPU 사용시
        "tree_method": 'exact', 'gpu_id': -1,  # CPU 사용시
        
        "gamma": trial.suggest_float("gamma", 0.1, 1.0, log=True),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.5, 1.0),
        "colsample_bynode": trial.suggest_float("colsample_bynode", 0.5, 1.0),
        "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
        "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
        # 'scale_pos_weight': scale_pos_weight
        # 'early_stopping_rounds': trial.suggest_int('early_stopping_rounds', 5, 20, step=5)
        
        # "learning_rate": trial.suggest_uniform('learning_rate', 0.0001, 0.99),
        # 'num_parallel_tree': trial.suggest_int("num_parallel_tree", 1, 500) 추가하면 느려짐.
    }

    model = xgb.XGBClassifier(**params, random_state = 42, use_label_encoder = False, n_jobs=-1)
    
    cv = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
    score = cross_val_score(model, X_train, y_train, cv=cv, scoring="f1", n_jobs=-1)
    f1_mean = score.mean()

    return f1_mean

# %%
RF_study = optuna.create_study()
RF_study.optimize(RF_objective, n_trials=200)
# Out:
# [I 2023-04-26 23:50:19,601] A new study created in memory with name: no-name-b61f6103-3712-4586-a3c8-93d1d1aeeeac
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:21,413] Trial 0 finished with value: 0.7821183888682486 and parameters: {'n_estimators': 250, 'max_depth': 9, 'gamma': 0.8678756128303354, 'min_child_weight': 2, 'subsample': 0.6, 'colsample_bytree': 0.9006150494370727, 'colsample_bylevel': 0.7878382757524767, 'colsample_bynode': 0.5624876743997655, 'reg_lambda': 0.037526927889356944, 'reg_alpha': 0.02150752011192643}. Best is trial 0 with value: 0.7821183888682486.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:22,184] Trial 1 finished with value: 0.7928892370165006 and parameters: {'n_estimators': 180, 'max_depth': 10, 'gamma': 0.2845101743842015, 'min_child_weight': 2, 'subsample': 1.0, 'colsample_bytree': 0.9553351893609117, 'colsample_bylevel': 0.5628414454516772, 'colsample_bynode': 0.6321536266202505, 'reg_lambda': 0.04218636271090789, 'reg_alpha': 0.04694861928618073}. Best is trial 0 with value: 0.7821183888682486.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:22,734] Trial 2 finished with value: 0.7683702446658238 and parameters: {'n_estimators': 940, 'max_depth': 8, 'gamma': 0.9978988733309542, 'min_child_weight': 5, 'subsample': 0.9, 'colsample_bytree': 0.7575846401606499, 'colsample_bylevel': 0.5720365339372309, 'colsample_bynode': 0.7364131564083871, 'reg_lambda': 0.07107450768225118, 'reg_alpha': 0.061781952204504074}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:23,213] Trial 3 finished with value: 0.7793437515142024 and parameters: {'n_estimators': 840, 'max_depth': 4, 'gamma': 0.6093404752076604, 'min_child_weight': 3, 'subsample': 0.9, 'colsample_bytree': 0.9254225584302822, 'colsample_bylevel': 0.6217883444090788, 'colsample_bynode': 0.8394299110439183, 'reg_lambda': 0.2687141312167385, 'reg_alpha': 0.19539838294514156}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:23,450] Trial 4 finished with value: 0.7702919583559132 and parameters: {'n_estimators': 310, 'max_depth': 6, 'gamma': 0.7904049892869343, 'min_child_weight': 3, 'subsample': 0.65, 'colsample_bytree': 0.8479516888836561, 'colsample_bylevel': 0.6663603497082276, 'colsample_bynode': 0.6788393423961576, 'reg_lambda': 0.02644291459590553, 'reg_alpha': 0.3610965057071022}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:23,648] Trial 5 finished with value: 0.7801374707546654 and parameters: {'n_estimators': 450, 'max_depth': 4, 'gamma': 0.9241573305216295, 'min_child_weight': 5, 'subsample': 0.75, 'colsample_bytree': 0.5647088797944483, 'colsample_bylevel': 0.5693594201427667, 'colsample_bynode': 0.6126265651135552, 'reg_lambda': 0.5767532448671823, 'reg_alpha': 0.522196907222511}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:24,148] Trial 6 finished with value: 0.7791988830743851 and parameters: {'n_estimators': 620, 'max_depth': 10, 'gamma': 0.22143993782121643, 'min_child_weight': 1, 'subsample': 0.7, 'colsample_bytree': 0.7512901541844789, 'colsample_bylevel': 0.7163749644159134, 'colsample_bynode': 0.8854909565771925, 'reg_lambda': 0.8643564864265398, 'reg_alpha': 0.7395266929925765}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:25,262] Trial 7 finished with value: 0.7889276201910318 and parameters: {'n_estimators': 440, 'max_depth': 7, 'gamma': 0.13761792563197772, 'min_child_weight': 1, 'subsample': 0.9, 'colsample_bytree': 0.7762202338043291, 'colsample_bylevel': 0.9849622064001847, 'colsample_bynode': 0.7694287189403743, 'reg_lambda': 0.011084514868395432, 'reg_alpha': 0.17741949899031}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:25,722] Trial 8 finished with value: 0.7706411269218283 and parameters: {'n_estimators': 850, 'max_depth': 8, 'gamma': 0.16142127453883745, 'min_child_weight': 4, 'subsample': 0.95, 'colsample_bytree': 0.549820807751036, 'colsample_bylevel': 0.987861648519228, 'colsample_bynode': 0.5670308582359624, 'reg_lambda': 0.20070743897686694, 'reg_alpha': 0.029554161366053752}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:26,175] Trial 9 finished with value: 0.7759151001281188 and parameters: {'n_estimators': 630, 'max_depth': 6, 'gamma': 0.4995709979305317, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.8720339741519882, 'colsample_bylevel': 0.6786737996890655, 'colsample_bynode': 0.8535639626741189, 'reg_lambda': 0.8495790861919195, 'reg_alpha': 0.09553675683876457}. Best is trial 2 with value: 0.7683702446658238.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:26,685] Trial 10 finished with value: 0.767707273834392 and parameters: {'n_estimators': 980, 'max_depth': 8, 'gamma': 0.44383975460174446, 'min_child_weight': 5, 'subsample': 0.85, 'colsample_bytree': 0.6929172138737807, 'colsample_bylevel': 0.5022393912000094, 'colsample_bynode': 0.97420382828655, 'reg_lambda': 0.11126019783667881, 'reg_alpha': 0.010107580830924178}. Best is trial 10 with value: 0.767707273834392.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:27,189] Trial 11 finished with value: 0.772618651780731 and parameters: {'n_estimators': 990, 'max_depth': 8, 'gamma': 0.4421493182969456, 'min_child_weight': 5, 'subsample': 0.85, 'colsample_bytree': 0.6552337305471065, 'colsample_bylevel': 0.5006568293525772, 'colsample_bynode': 0.9946637030407809, 'reg_lambda': 0.09400188118705356, 'reg_alpha': 0.011266404550626328}. Best is trial 10 with value: 0.767707273834392.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:27,669] Trial 12 finished with value: 0.7591338073858998 and parameters: {'n_estimators': 1000, 'max_depth': 8, 'gamma': 0.4438765860179343, 'min_child_weight': 5, 'subsample': 0.8, 'colsample_bytree': 0.6690724876316965, 'colsample_bylevel': 0.502470463232276, 'colsample_bynode': 0.722760229362376, 'reg_lambda': 0.10136784151587336, 'reg_alpha': 0.01011430787679251}. Best is trial 12 with value: 0.7591338073858998.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:28,079] Trial 13 finished with value: 0.7665851319710562 and parameters: {'n_estimators': 740, 'max_depth': 7, 'gamma': 0.3661309915074006, 'min_child_weight': 4, 'subsample': 0.8, 'colsample_bytree': 0.6637812131977768, 'colsample_bylevel': 0.5011402087033225, 'colsample_bynode': 0.9720390844538439, 'reg_lambda': 0.15274314508843045, 'reg_alpha': 0.010723815744076015}. Best is trial 12 with value: 0.7591338073858998.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:28,482] Trial 14 finished with value: 0.7623390991313233 and parameters: {'n_estimators': 780, 'max_depth': 6, 'gamma': 0.3464424812586686, 'min_child_weight': 4, 'subsample': 0.75, 'colsample_bytree': 0.636289345440263, 'colsample_bylevel': 0.5260771886371577, 'colsample_bynode': 0.749832402158945, 'reg_lambda': 0.21238922852528028, 'reg_alpha': 0.016601541413984244}. Best is trial 12 with value: 0.7591338073858998.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:28,836] Trial 15 finished with value: 0.759500835156486 and parameters: {'n_estimators': 810, 'max_depth': 5, 'gamma': 0.2821033211987599, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 0.5925441601646637, 'colsample_bylevel': 0.6113988316107738, 'colsample_bynode': 0.5094507421358573, 'reg_lambda': 0.2886368758893012, 'reg_alpha': 0.022100608823620454}. Best is trial 12 with value: 0.7591338073858998.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:29,161] Trial 16 finished with value: 0.7601325154472713 and parameters: {'n_estimators': 720, 'max_depth': 5, 'gamma': 0.24958114295003206, 'min_child_weight': 4, 'subsample': 0.7, 'colsample_bytree': 0.502441329901496, 'colsample_bylevel': 0.6146756851912658, 'colsample_bynode': 0.5210492965057228, 'reg_lambda': 0.42347912234466834, 'reg_alpha': 0.030894642575287918}. Best is trial 12 with value: 0.7591338073858998.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:29,553] Trial 17 finished with value: 0.7519840460788509 and parameters: {'n_estimators': 870, 'max_depth': 5, 'gamma': 0.19550259478186163, 'min_child_weight': 5, 'subsample': 0.65, 'colsample_bytree': 0.5836759936772795, 'colsample_bylevel': 0.6034197611523788, 'colsample_bynode': 0.6688928714747644, 'reg_lambda': 0.3284278083430985, 'reg_alpha': 0.01875648807578924}. Best is trial 17 with value: 0.7519840460788509.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:30,027] Trial 18 finished with value: 0.7424300854741224 and parameters: {'n_estimators': 900, 'max_depth': 5, 'gamma': 0.20521056707850666, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7109192702343852, 'colsample_bylevel': 0.779616659181764, 'colsample_bynode': 0.6853533281506449, 'reg_lambda': 0.39857961009569826, 'reg_alpha': 0.01606952885873559}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:30,449] Trial 19 finished with value: 0.7598109051592471 and parameters: {'n_estimators': 640, 'max_depth': 5, 'gamma': 0.1005109513625612, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.9962691451662247, 'colsample_bylevel': 0.7885627735145886, 'colsample_bynode': 0.6513637750878464, 'reg_lambda': 0.4471616602727526, 'reg_alpha': 0.0445727973511551}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:30,918] Trial 20 finished with value: 0.7586779130164526 and parameters: {'n_estimators': 900, 'max_depth': 4, 'gamma': 0.19906681393928805, 'min_child_weight': 5, 'subsample': 0.65, 'colsample_bytree': 0.7144455420254084, 'colsample_bylevel': 0.751214041637776, 'colsample_bynode': 0.683837701587173, 'reg_lambda': 0.3453781712669948, 'reg_alpha': 0.017546091572158567}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:31,380] Trial 21 finished with value: 0.7582323810759536 and parameters: {'n_estimators': 880, 'max_depth': 4, 'gamma': 0.20270360768187778, 'min_child_weight': 5, 'subsample': 0.65, 'colsample_bytree': 0.7121453046946395, 'colsample_bylevel': 0.760343530583611, 'colsample_bynode': 0.678727542041958, 'reg_lambda': 0.3350833523676337, 'reg_alpha': 0.017517439895963466}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:31,826] Trial 22 finished with value: 0.7608339208295332 and parameters: {'n_estimators': 900, 'max_depth': 5, 'gamma': 0.17994291390838663, 'min_child_weight': 5, 'subsample': 0.65, 'colsample_bytree': 0.6223402490946812, 'colsample_bylevel': 0.8213052823659623, 'colsample_bynode': 0.6224575081187133, 'reg_lambda': 0.5804338499247642, 'reg_alpha': 0.03204536223060259}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:32,239] Trial 23 finished with value: 0.7501776383898848 and parameters: {'n_estimators': 710, 'max_depth': 4, 'gamma': 0.23270452096907424, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8131406693329492, 'colsample_bylevel': 0.8177556774861389, 'colsample_bynode': 0.6943584768606503, 'reg_lambda': 0.30412020883931284, 'reg_alpha': 0.018036465252649507}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:32,730] Trial 24 finished with value: 0.7585219099494583 and parameters: {'n_estimators': 710, 'max_depth': 5, 'gamma': 0.2477372855065853, 'min_child_weight': 4, 'subsample': 0.6, 'colsample_bytree': 0.8129898595946914, 'colsample_bylevel': 0.8350125892400357, 'colsample_bynode': 0.7853365590430533, 'reg_lambda': 0.18923289542875288, 'reg_alpha': 0.025727376865372225}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:33,083] Trial 25 finished with value: 0.7520489929583096 and parameters: {'n_estimators': 540, 'max_depth': 6, 'gamma': 0.15578361107580588, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.8005516082280338, 'colsample_bylevel': 0.8721655136822869, 'colsample_bynode': 0.7054975567120743, 'reg_lambda': 0.593595604369608, 'reg_alpha': 0.016658231941446697}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:50:33,493] Trial 26 finished with value: 0.7575318251278984 and parameters: {'n_estimators': 770, 'max_depth': 4, 'gamma': 0.21908684315138807, 'min_child_weight': 3, 'subsample': 0.6, 'colsample_bytree': 0.7179184853870397, 'colsample_bylevel': 0.7111666410746744, 'colsample_bynode': 0.7122626831367778, 'reg_lambda': 0.26748825063768306, 'reg_alpha': 0.0411950736743029}. Best is trial 18 with value: 0.7424300854741224.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# ...
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:48,541] Trial 191 finished with value: 0.756233762546832 and parameters: {'n_estimators': 180, 'max_depth': 6, 'gamma': 0.16213993311421923, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6918784285853022, 'colsample_bylevel': 0.8032837319996932, 'colsample_bynode': 0.7637009704702035, 'reg_lambda': 0.2521858917067401, 'reg_alpha': 0.03897387721591348}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:48,895] Trial 192 finished with value: 0.7635632456756566 and parameters: {'n_estimators': 520, 'max_depth': 6, 'gamma': 0.14651695207110196, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6708006025594627, 'colsample_bylevel': 0.8409020619859748, 'colsample_bynode': 0.7511835791024273, 'reg_lambda': 0.40694572052245104, 'reg_alpha': 0.04338745172298375}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:49,461] Trial 193 finished with value: 0.7645763110831278 and parameters: {'n_estimators': 890, 'max_depth': 6, 'gamma': 0.13976945529884943, 'min_child_weight': 5, 'subsample': 0.85, 'colsample_bytree': 0.6583352461656002, 'colsample_bylevel': 0.6836118330190232, 'colsample_bynode': 0.7705478968741615, 'reg_lambda': 0.11859856806573885, 'reg_alpha': 0.034464434020265465}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:49,955] Trial 194 finished with value: 0.7546052852882419 and parameters: {'n_estimators': 930, 'max_depth': 6, 'gamma': 0.27871999188893526, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6439004302425106, 'colsample_bylevel': 0.6729190909666574, 'colsample_bynode': 0.7178385447539174, 'reg_lambda': 0.32660177368163845, 'reg_alpha': 0.0317119947255857}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:50,514] Trial 195 finished with value: 0.7525947936072691 and parameters: {'n_estimators': 910, 'max_depth': 7, 'gamma': 0.12609124991779974, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.6806821893701253, 'colsample_bylevel': 0.7713456496546737, 'colsample_bynode': 0.7439611259098718, 'reg_lambda': 0.5072639158389745, 'reg_alpha': 0.039897775821581175}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:51,089] Trial 196 finished with value: 0.7444565267195031 and parameters: {'n_estimators': 960, 'max_depth': 6, 'gamma': 0.14764658944634274, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7057826916235579, 'colsample_bylevel': 0.7925948728527152, 'colsample_bynode': 0.7336723596608858, 'reg_lambda': 0.10033748633397718, 'reg_alpha': 0.04750745382815872}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:51,664] Trial 197 finished with value: 0.7586967681662737 and parameters: {'n_estimators': 990, 'max_depth': 6, 'gamma': 0.15308856895356102, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7041655791749024, 'colsample_bylevel': 0.7872557430566485, 'colsample_bynode': 0.7284075892197204, 'reg_lambda': 0.0871481361573506, 'reg_alpha': 0.0441772337882846}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:52,227] Trial 198 finished with value: 0.7516701892382482 and parameters: {'n_estimators': 960, 'max_depth': 6, 'gamma': 0.17591335179904105, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.728714410322682, 'colsample_bylevel': 0.7557067301746275, 'colsample_bynode': 0.6907020408318774, 'reg_lambda': 0.1167159501154657, 'reg_alpha': 0.04664999137622828}. Best is trial 111 with value: 0.7351550285482402.
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:14: FutureWarning: suggest_discrete_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   'subsample': trial.suggest_discrete_uniform('subsample', 0.6, 1.0, 0.05),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_lambda": trial.suggest_loguniform("reg_lambda", 1e-2, 1),
# /var/folders/1q/v9gxtgcn3bl6qw0ln1qykht40000gp/T/ipykernel_31829/1160535097.py:19: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use :func:`~optuna.trial.Trial.suggest_float` instead.
#   "reg_alpha": trial.suggest_loguniform("reg_alpha", 1e-2, 1),
# /Users/min/anaconda3/lib/python3.10/site-packages/xgboost/sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# [I 2023-04-26 23:51:52,821] Trial 199 finished with value: 0.7583587501269347 and parameters: {'n_estimators': 980, 'max_depth': 5, 'gamma': 0.19092400345638827, 'min_child_weight': 5, 'subsample': 0.6, 'colsample_bytree': 0.7135895661889726, 'colsample_bylevel': 0.7423855751014856, 'colsample_bynode': 0.7354186839566706, 'reg_lambda': 0.09888084224045021, 'reg_alpha': 0.05013124117768436}. Best is trial 111 with value: 0.7351550285482402.

# %%
RF_study.best_params
# Out:
# {'n_estimators': 620,
#  'max_depth': 9,
#  'gamma': 0.17495405615920656,
#  'min_child_weight': 5,
#  'subsample': 0.65,
#  'colsample_bytree': 0.7550164083642951,
#  'colsample_bylevel': 0.5698778796912594,
#  'colsample_bynode': 0.7743481974769857,
#  'reg_lambda': 0.25137400709293717,
#  'reg_alpha': 0.015636013665511015}

# %%
rfc = xgb.XGBClassifier(**RF_study.best_params, objective='binary:logistic', eval_metric='auc', booster='gbtree', random_state = 42, use_label_encoder = False, n_jobs=-1)

# %%
rfc.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=0.5698778796912594,
#               colsample_bynode=0.7743481974769857,
#               colsample_bytree=0.7550164083642951, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=0.17495405615920656, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=9,
#               max_leaves=None, min_child_weight=5, missing=nan,
#               monotone_constraints=None, n_estimators=620, n_jobs=-1,
#               num_parallel_tree=None, predictor=None, random_state=42, ...)

# %%
y_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test, y_pred, target_names=['No Frauds', 'Frauds']))
# Out:
#               precision    recall  f1-score   support
#
#    No Frauds       0.76      0.74      0.75       100
#       Frauds       0.75      0.76      0.75       100
#
#     accuracy                           0.75       200
#    macro avg       0.75      0.75      0.75       200
# weighted avg       0.75      0.75      0.75       200

# %%
classification_report(y_test, y_pred, target_names=['No Frauds', 'Frauds'], output_dict=True)
# Out:
# {'No Frauds': {'precision': 0.7551020408163265,
#   'recall': 0.74,
#   'f1-score': 0.7474747474747474,
#   'support': 100},
#  'Frauds': {'precision': 0.7450980392156863,
#   'recall': 0.76,
#   'f1-score': 0.7524752475247525,
#   'support': 100},
#  'accuracy': 0.75,
#  'macro avg': {'precision': 0.7501000400160064,
#   'recall': 0.75,
#   'f1-score': 0.7499749974997499,
#   'support': 200},
#  'weighted avg': {'precision': 0.7501000400160064,
#   'recall': 0.75,
#   'f1-score': 0.7499749974997499,
#   'support': 200}}

# %%
precision = classification_report(y_test, y_pred, target_names=['No Frauds', 'Frauds'], output_dict=True)['macro avg']['precision']
precision
# Out:
# 0.7501000400160064

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic') 

fig, ax = plt.subplots(figsize=(10, 20))
xgb.plot_importance(rfc, ax=ax)
plt.show()
